# %% [markdown]
# <a href="https://colab.research.google.com/github/yuanshitianzong/Project_ChurnPrediction/blob/main/ChurnPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Context:
# You were hired as a data scientist by telecommunications operator Alura Voz.
# In the initial meeting with the people responsible for the company's sales area, the importance of reducing the Customer Evasion Rate, known as Churn Rate, was explained.
# Basically, the Churn Rate indicates how much the company lost in revenue or customers over a period of time.
# With your experience, you suggest, as an initial step, identifying customers who are most likely to leave the company.
# To do this, you explain that it is interesting to investigate some characteristics of clients or client plans to try to CLASSIFY these people as potential candidates to leave the company or not.
# So, you request the dataset to start exploring, processing and modeling from now on. Next, the focus will be on optimizing each of the models in order to obtain
# the best result for Alura Voz's decision-making.
# Meaning of the variables in the dataset:
# customerID: unique identification number for each customer
# Churn: whether or not the customer left the company
# gender: gender (male and female)
# SeniorCitizen: information about whether or not a customer is 65 years old or older
# Partner: whether or not the client has a partner
# Dependents: whether or not the client has dependents
# tenure: months of customer contract
# PhoneService: telephone service subscription
# MultipleLines: subscribing to more than one telephone line
# InternetService: subscription to an internet provider
# OnlineSecurity: additional online security subscription
# OnlineBackup: additional online backup subscription
# DeviceProtection: additional on-device protection subscription
# TechSupport: additional technical support subscription, less waiting time
# StreamingTV: cable TV subscription
# StreamingMovies: movie streaming subscription
# Contract: type of contract
# PaperlessBilling: if the customer prefers to receive the invoice online
# PaymentMethod: payment method
# Charges.Monthly: total income from all hired customer services per month
# Charges.Total: total spent by the customer

# %%
# Importimg some important libraries
import pandas as pd
import numpy as np

# %%
# Loading and visualizing an overview of the data
file = pd.read_json('https://raw.githubusercontent.com/sthemonica/alura-voz/main/Dados/Telco-Customer-Churn.json')
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
# Seeing how the data looks. A lot of information is clustered together in a single column, so we need separate those into their own columns.
file.head(10)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5  0013-MHZWF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6  0013-SMEOE    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 7  0014-BMAQU    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 8  0015-UOCOJ    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 9  0016-QLJIS    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 5   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 6   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 8   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 9  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 5  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 6  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 8  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 9  {'InternetService': 'DSL', 'OnlineSecurity': '...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 5  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 6  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7  {'Contract': 'Two year', 'PaperlessBilling': '...
# 8  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 9  {'Contract': 'Two year', 'PaperlessBilling': '...

# %%
# Assigning the data to a variable so we can change it without changing the original data.
df = file

# %%
# Separating all the clustered data into different columns and setting the index to the customer ID
df2 = pd.concat([df,pd.DataFrame(file['customer'].to_list())],axis=1)
df2 = pd.concat([df2,pd.DataFrame(file['phone'].to_list())],axis=1)
df2 = pd.concat([df2,pd.DataFrame(file['internet'].to_list())],axis=1)
df2 = pd.concat([df2,pd.DataFrame(file['account'].to_list())],axis=1)
df2 = pd.concat([df2,pd.DataFrame(df2['Charges'].to_list())],axis=1)
df2.drop(['customer','phone','internet','account','Charges'],axis=1,inplace=True)
df2.set_index('customerID',inplace=True)
df2
# Out:
#            Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# customerID
# 0002-ORFBO    No  Female              0     Yes        Yes       9
# 0003-MKNFE    No    Male              0      No         No       9
# 0004-TLHLJ   Yes    Male              0      No         No       4
# 0011-IGKFF   Yes    Male              1     Yes         No      13
# 0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...     ...            ...     ...        ...     ...
# 9987-LUTYD    No  Female              0      No         No      13
# 9992-RRAMN   Yes    Male              0     Yes         No      22
# 9992-UJOEL    No    Male              0      No         No       2
# 9993-LHIEB    No    Male              0     Yes        Yes      67
# 9995-HOTOH    No    Male              0     Yes        Yes      63
#
#            PhoneService     MultipleLines InternetService OnlineSecurity  \
# customerID
# 0002-ORFBO          Yes                No             DSL             No
# 0003-MKNFE          Yes               Yes             DSL             No
# 0004-TLHLJ          Yes                No     Fiber optic             No
# 0011-IGKFF          Yes                No     Fiber optic             No
# 0013-EXCHZ          Yes                No     Fiber optic             No
# ...                 ...               ...             ...            ...
# 9987-LUTYD          Yes                No             DSL            Yes
# 9992-RRAMN          Yes               Yes     Fiber optic             No
# 9992-UJOEL          Yes                No             DSL             No
# 9993-LHIEB          Yes                No             DSL            Yes
# 9995-HOTOH           No  No phone service             DSL            Yes
#
#            OnlineBackup DeviceProtection TechSupport StreamingTV  \
# customerID
# 0002-ORFBO          Yes               No         Yes         Yes
# 0003-MKNFE           No               No          No          No
# 0004-TLHLJ           No              Yes          No          No
# 0011-IGKFF          Yes              Yes          No         Yes
# 0013-EXCHZ           No               No         Yes         Yes
# ...                 ...              ...         ...         ...
# 9987-LUTYD           No               No         Yes          No
# 9992-RRAMN           No               No          No          No
# 9992-UJOEL          Yes               No          No          No
# 9993-LHIEB           No              Yes         Yes          No
# 9995-HOTOH          Yes              Yes          No         Yes
#
#            StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# customerID
# 0002-ORFBO              No        One year              Yes      Mailed check
# 0003-MKNFE             Yes  Month-to-month               No      Mailed check
# 0004-TLHLJ              No  Month-to-month              Yes  Electronic check
# 0011-IGKFF             Yes  Month-to-month              Yes  Electronic check
# 0013-EXCHZ              No  Month-to-month              Yes      Mailed check
# ...                    ...             ...              ...               ...
# 9987-LUTYD              No        One year               No      Mailed check
# 9992-RRAMN             Yes  Month-to-month              Yes  Electronic check
# 9992-UJOEL              No  Month-to-month              Yes      Mailed check
# 9993-LHIEB             Yes        Two year               No      Mailed check
# 9995-HOTOH             Yes        Two year               No  Electronic check
#
#             Monthly    Total
# customerID
# 0002-ORFBO    65.60    593.3
# 0003-MKNFE    59.90    542.4
# 0004-TLHLJ    73.90   280.85
# 0011-IGKFF    98.00  1237.85
# 0013-EXCHZ    83.90    267.4
# ...             ...      ...
# 9987-LUTYD    55.15    742.9
# 9992-RRAMN    85.10   1873.7
# 9992-UJOEL    50.30    92.75
# 9993-LHIEB    67.85  4627.65
# 9995-HOTOH    59.00   3707.6
#
# [7267 rows x 20 columns]

# %%
df2['Churn'].unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
# After checking the unique values in each column of the dataframe, we could see that there were inconsistencies in the data. For 224 of the entries,
# there was no value assigned to the "Churn" column, which I opted for removing from the dataset. The "Total" and "SeniorCitizen" columns had the wrong dtype
# Some entries on the "Total" column were empty as well. Finally, it`s important to check inconsistencies in the additional services.

print('number of blank Total entries is '+ str(df2.query('Total==" "').shape[0]))
print('number of empty Churn entries is ' + str(df2.query('Churn==""').shape[0]))
print('number of inconsistent OnlineSecurity entries is ' + str(df2.query('InternetService=="No" and OnlineSecurity=="Yes"').shape[0]))
print('number of inconsistent OnlineBackup entries is ' + str(df2.query('InternetService=="No" and OnlineBackup=="Yes"').shape[0]))
print('number of inconsistent DeviceProtection entries is ' + str(df2.query('InternetService=="No" and DeviceProtection=="Yes"').shape[0]))
print('number of inconsistent TechSupport entries is ' + str(df2.query('InternetService=="No" and TechSupport=="Yes"').shape[0]))
print('number of inconsistent StreamingTV entries is ' + str(df2.query('InternetService=="No" and StreamingTV=="Yes"').shape[0]))
print('number of inconsistent StreamingMovies entries is ' + str(df2.query('InternetService=="No" and StreamingMovies=="Yes"').shape[0]))
print('number of inconsistent MultipleLines entries is ' + str(df2.query('PhoneService=="No" and MultipleLines=="Yes"').shape[0]))
# Out:
# number of blank Total entries is 11
# number of empty Churn entries is 224
# number of inconsistent OnlineSecurity entries is 0
# number of inconsistent OnlineBackup entries is 0
# number of inconsistent DeviceProtection entries is 0
# number of inconsistent TechSupport entries is 0
# number of inconsistent StreamingTV entries is 0
# number of inconsistent StreamingMovies entries is 0
# number of inconsistent MultipleLines entries is 0

# %%
# Removing inconsistent data.
df3 = df2.drop(df2.query('Churn==""').index,axis=0)
df3 = df3.drop(df3.query('Total==" "').index,axis=0)
df3
# Out:
#            Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# customerID
# 0002-ORFBO    No  Female              0     Yes        Yes       9
# 0003-MKNFE    No    Male              0      No         No       9
# 0004-TLHLJ   Yes    Male              0      No         No       4
# 0011-IGKFF   Yes    Male              1     Yes         No      13
# 0013-EXCHZ   Yes  Female              1     Yes         No       3
# ...          ...     ...            ...     ...        ...     ...
# 9987-LUTYD    No  Female              0      No         No      13
# 9992-RRAMN   Yes    Male              0     Yes         No      22
# 9992-UJOEL    No    Male              0      No         No       2
# 9993-LHIEB    No    Male              0     Yes        Yes      67
# 9995-HOTOH    No    Male              0     Yes        Yes      63
#
#            PhoneService     MultipleLines InternetService OnlineSecurity  \
# customerID
# 0002-ORFBO          Yes                No             DSL             No
# 0003-MKNFE          Yes               Yes             DSL             No
# 0004-TLHLJ          Yes                No     Fiber optic             No
# 0011-IGKFF          Yes                No     Fiber optic             No
# 0013-EXCHZ          Yes                No     Fiber optic             No
# ...                 ...               ...             ...            ...
# 9987-LUTYD          Yes                No             DSL            Yes
# 9992-RRAMN          Yes               Yes     Fiber optic             No
# 9992-UJOEL          Yes                No             DSL             No
# 9993-LHIEB          Yes                No             DSL            Yes
# 9995-HOTOH           No  No phone service             DSL            Yes
#
#            OnlineBackup DeviceProtection TechSupport StreamingTV  \
# customerID
# 0002-ORFBO          Yes               No         Yes         Yes
# 0003-MKNFE           No               No          No          No
# 0004-TLHLJ           No              Yes          No          No
# 0011-IGKFF          Yes              Yes          No         Yes
# 0013-EXCHZ           No               No         Yes         Yes
# ...                 ...              ...         ...         ...
# 9987-LUTYD           No               No         Yes          No
# 9992-RRAMN           No               No          No          No
# 9992-UJOEL          Yes               No          No          No
# 9993-LHIEB           No              Yes         Yes          No
# 9995-HOTOH          Yes              Yes          No         Yes
#
#            StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# customerID
# 0002-ORFBO              No        One year              Yes      Mailed check
# 0003-MKNFE             Yes  Month-to-month               No      Mailed check
# 0004-TLHLJ              No  Month-to-month              Yes  Electronic check
# 0011-IGKFF             Yes  Month-to-month              Yes  Electronic check
# 0013-EXCHZ              No  Month-to-month              Yes      Mailed check
# ...                    ...             ...              ...               ...
# 9987-LUTYD              No        One year               No      Mailed check
# 9992-RRAMN             Yes  Month-to-month              Yes  Electronic check
# 9992-UJOEL              No  Month-to-month              Yes      Mailed check
# 9993-LHIEB             Yes        Two year               No      Mailed check
# 9995-HOTOH             Yes        Two year               No  Electronic check
#
#             Monthly    Total
# customerID
# 0002-ORFBO    65.60    593.3
# 0003-MKNFE    59.90    542.4
# 0004-TLHLJ    73.90   280.85
# 0011-IGKFF    98.00  1237.85
# 0013-EXCHZ    83.90    267.4
# ...             ...      ...
# 9987-LUTYD    55.15    742.9
# 9992-RRAMN    85.10   1873.7
# 9992-UJOEL    50.30    92.75
# 9993-LHIEB    67.85  4627.65
# 9995-HOTOH    59.00   3707.6
#
# [7032 rows x 20 columns]

# %%
# Changing the column Total to float and SeniorCitizen to object
df3['Total'] = df3['Total'].astype('float64')
df3['SeniorCitizen'] = df3['SeniorCitizen'].astype('object')
print(df3.dtypes)
# Out:
# Churn                object
# gender               object
# SeniorCitizen        object
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# Monthly             float64
# Total               float64
# dtype: object

# %%
# The SeniorCitizen column indicates if a customer is over 65 years old or not. it`s a categorical information, and for visualization purpouses it`s better defined as "Yes" or "No".
df3['SeniorCitizen'].replace([0,1],['No','Yes'],inplace=True)
df3['SeniorCitizen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Importing libraries
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Creating a dataframe with the proportion of Churn rate in the dataset.
Churn = df3['Churn'].value_counts(normalize=True)
Churn
# Out:
# Churn
# No     0.734215
# Yes    0.265785
# Name: proportion, dtype: float64

# %%
# Plotting to visualize the churn rate proportion
fig,ax = plt.subplots()
Churn.plot(kind='bar',ax=ax,rot=0)
plt.title('Current Churn rate (in %)')
ax.set_yticklabels([])
ax.tick_params(length=0)
ax.set_frame_on(False)
for container in ax.containers:
  labels = [f'{valor.get_height()*100:.0f}%' for valor in container]
  ax.bar_label(container,label_type='center',labels=labels,size=10,color='#414040',fontweight='bold')

# %%
# Ploting some of the categorical data to see the relation between those variables and the Churn rate. We can see that the SeniorCitizen, Partner and Dependents features
# seem to have an influence on the Churn rate.
n = 0
fig = plt.subplots(figsize=(14,15))
for column in ['SeniorCitizen','gender','Partner','Dependents','PhoneService']:
  n = n+1
  df_churn = pd.crosstab(index=df3[column],columns=df3['Churn'],normalize='index')
  ax = plt.subplot(3,2,n)
  df_churn.plot(kind='bar',ax=ax,rot=0)
  ax.set_title(f'Relation between {column} and Churn')
  ax.set_yticklabels([])
  ax.tick_params(length=0)
  ax.set_frame_on(False)

  for container in ax.containers:
   labels = [f'{valor.get_height()*100:.0f}%' for valor in container]
   ax.bar_label(container,label_type='center',labels=labels,size=10,color='#414040',fontweight='bold')
# Out:
# <ipython-input-15-61b2410cd941>:8: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(3,2,n)

# %%
# Likewise, checking the effect on the churn rate of more categorical variables. The InternetService feature have additional services associated with it.
# In this graph, we investigate the internet services alone, and, if any effect is visualized, we further breakdown the relation between those additional
# services and the target variable. The exploration of this data already provides us with possibly useful insights. Among the clients that hire Internet
# services, there is much smaller churn rate in the ones with DSL services when compared to optic fiber. We can also notice a progressively decreasing
# Churn rate with the longer term contracts, and, surprisingly, a higher churn with clients who opt for paperless biling. These observations gives us hints
# on what services we could offer, once the algorithm poits us to the clients more likely to churn, in order to attempt to prevent that client's evasion.
n = 0
fig = plt.subplots(figsize=(15,12))
for column in ['InternetService','Contract','PaperlessBilling','PaymentMethod']:
  n = n+1
  df_churn = pd.crosstab(index=df3[column],columns=df3['Churn'],normalize='index')
  ax = plt.subplot(2,2,n)
  df_churn.plot(kind='bar',ax=ax,rot=20)
  ax.set_title(f'Relation between {column} and Churn')
  ax.set_yticklabels([])
  ax.set_xlabel('')
  ax.tick_params(length=0)
  ax.set_frame_on(False)

  for container in ax.containers:
   labels = [f'{valor.get_height()*100:.0f}%' for valor in container]
   ax.bar_label(container,label_type='center',labels=labels,size=10,color='#414040',fontweight='bold')
# Out:
# <ipython-input-16-086b1fdbd321>:12: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(2,2,n)

# %%
# Now, looking at the additional internet services. All features but streaming tv and streaming movies seemed to have a significant effect on churn. Like in the previous analysis, we can also notice
# potentialy interesting things on these graphs. Apparently, the subscription to online securyty, online backup, device protection andd tech support services increase client fidelity, and  potentialy
# decrease the Churn rate.
n = 0
fig = plt.subplots(figsize=(12,15))
for column in ['OnlineSecurity','OnlineBackup',	'DeviceProtection','TechSupport','StreamingTV','StreamingMovies']:
  n = n+1
  df_churn = pd.crosstab(index=df3[column],columns=df3['Churn'],normalize='index')
  ax = plt.subplot(3,2,n)
  df_churn.plot(kind='bar',ax=ax,rot=0)
  ax.set_title(f'Relation between {column} and Churn')
  ax.set_yticklabels([])
  ax.set_xlabel('')
  ax.tick_params(length=0)
  ax.set_frame_on(False)

  for container in ax.containers:
   labels = [f'{valor.get_height()*100:.0f}%' for valor in container]
   ax.bar_label(container,label_type='center',labels=labels,size=10,color='#414040',fontweight='bold')
# Out:
# <ipython-input-17-1a6c70e2776c>:9: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(3,2,n)

# %%
# Time to look at the numerical variables and their relation with the churn rate. As expected, higher fees and shorter tenure durations are potentialy related to
# higher churn rates.
n = 0
fig = plt.subplots(figsize=(15,10))
for num_columns in ['tenure','Monthly','Total']:
  n=n+1
  ax = plt.subplot(2,2,n)
  sns.violinplot(df3,x=num_columns,y='Churn',orient='h')
  x_labels = ['Tenure duration','Monthly Payment','Total Payment']
  ax.set_title(f'Relation between {x_labels[n-1]} and Churn')
  ax.set_xlabel('')
  ax.set_frame_on(False)
  ax.tick_params(length=0)
# Out:
# <ipython-input-18-512914764e3d>:7: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = plt.subplot(2,2,n)

# %%
# Removing the less informative features. Those features might be reconsidered depending on the initial performance of the algorithm.
df_trimmed = df3.drop(['gender','PhoneService','MultipleLines','StreamingTV','StreamingMovies','PaymentMethod'],axis=1)
df_trimmed
# Out:
#            Churn SeniorCitizen Partner Dependents  tenure InternetService  \
# customerID
# 0002-ORFBO    No            No     Yes        Yes       9             DSL
# 0003-MKNFE    No            No      No         No       9             DSL
# 0004-TLHLJ   Yes            No      No         No       4     Fiber optic
# 0011-IGKFF   Yes           Yes     Yes         No      13     Fiber optic
# 0013-EXCHZ   Yes           Yes     Yes         No       3     Fiber optic
# ...          ...           ...     ...        ...     ...             ...
# 9987-LUTYD    No            No      No         No      13             DSL
# 9992-RRAMN   Yes            No     Yes         No      22     Fiber optic
# 9992-UJOEL    No            No      No         No       2             DSL
# 9993-LHIEB    No            No     Yes        Yes      67             DSL
# 9995-HOTOH    No            No     Yes        Yes      63             DSL
#
#            OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# customerID
# 0002-ORFBO             No          Yes               No         Yes
# 0003-MKNFE             No           No               No          No
# 0004-TLHLJ             No           No              Yes          No
# 0011-IGKFF             No          Yes              Yes          No
# 0013-EXCHZ             No           No               No         Yes
# ...                   ...          ...              ...         ...
# 9987-LUTYD            Yes           No               No         Yes
# 9992-RRAMN             No           No               No          No
# 9992-UJOEL             No          Yes               No          No
# 9993-LHIEB            Yes           No              Yes         Yes
# 9995-HOTOH            Yes          Yes              Yes          No
#
#                   Contract PaperlessBilling  Monthly    Total
# customerID
# 0002-ORFBO        One year              Yes    65.60   593.30
# 0003-MKNFE  Month-to-month               No    59.90   542.40
# 0004-TLHLJ  Month-to-month              Yes    73.90   280.85
# 0011-IGKFF  Month-to-month              Yes    98.00  1237.85
# 0013-EXCHZ  Month-to-month              Yes    83.90   267.40
# ...                    ...              ...      ...      ...
# 9987-LUTYD        One year               No    55.15   742.90
# 9992-RRAMN  Month-to-month              Yes    85.10  1873.70
# 9992-UJOEL  Month-to-month              Yes    50.30    92.75
# 9993-LHIEB        Two year               No    67.85  4627.65
# 9995-HOTOH        Two year               No    59.00  3707.60
#
# [7032 rows x 14 columns]

# %%
# Coding the Churn variable
df_trimmed['Churn'].replace(['Yes','No'],[1,0],inplace=True)

# %%
# One hot encoding
data = pd.get_dummies(df_trimmed,dtype='int')
data
# Out:
#             Churn  tenure  Monthly    Total  SeniorCitizen_No  \
# customerID
# 0002-ORFBO      0       9    65.60   593.30                 1
# 0003-MKNFE      0       9    59.90   542.40                 1
# 0004-TLHLJ      1       4    73.90   280.85                 1
# 0011-IGKFF      1      13    98.00  1237.85                 0
# 0013-EXCHZ      1       3    83.90   267.40                 0
# ...           ...     ...      ...      ...               ...
# 9987-LUTYD      0      13    55.15   742.90                 1
# 9992-RRAMN      1      22    85.10  1873.70                 1
# 9992-UJOEL      0       2    50.30    92.75                 1
# 9993-LHIEB      0      67    67.85  4627.65                 1
# 9995-HOTOH      0      63    59.00  3707.60                 1
#
#             SeniorCitizen_Yes  Partner_No  Partner_Yes  Dependents_No  \
# customerID
# 0002-ORFBO                  0           0            1              0
# 0003-MKNFE                  0           1            0              1
# 0004-TLHLJ                  0           1            0              1
# 0011-IGKFF                  1           0            1              1
# 0013-EXCHZ                  1           0            1              1
# ...                       ...         ...          ...            ...
# 9987-LUTYD                  0           1            0              1
# 9992-RRAMN                  0           0            1              1
# 9992-UJOEL                  0           1            0              1
# 9993-LHIEB                  0           0            1              0
# 9995-HOTOH                  0           0            1              0
#
#             Dependents_Yes  ...  DeviceProtection_No internet service  \
# customerID                  ...
# 0002-ORFBO               1  ...                                     0
# 0003-MKNFE               0  ...                                     0
# 0004-TLHLJ               0  ...                                     0
# 0011-IGKFF               0  ...                                     0
# 0013-EXCHZ               0  ...                                     0
# ...                    ...  ...                                   ...
# 9987-LUTYD               0  ...                                     0
# 9992-RRAMN               0  ...                                     0
# 9992-UJOEL               0  ...                                     0
# 9993-LHIEB               1  ...                                     0
# 9995-HOTOH               1  ...                                     0
#
#             DeviceProtection_Yes  TechSupport_No  \
# customerID
# 0002-ORFBO                     0               0
# 0003-MKNFE                     0               1
# 0004-TLHLJ                     1               1
# 0011-IGKFF                     1               1
# 0013-EXCHZ                     0               0
# ...                          ...             ...
# 9987-LUTYD                     0               0
# 9992-RRAMN                     0               1
# 9992-UJOEL                     0               1
# 9993-LHIEB                     1               0
# 9995-HOTOH                     1               1
#
#             TechSupport_No internet service  TechSupport_Yes  \
# customerID
# 0002-ORFBO                                0                1
# 0003-MKNFE                                0                0
# 0004-TLHLJ                                0                0
# 0011-IGKFF                                0                0
# 0013-EXCHZ                                0                1
# ...                                     ...              ...
# 9987-LUTYD                                0                1
# 9992-RRAMN                                0                0
# 9992-UJOEL                                0                0
# 9993-LHIEB                                0                1
# 9995-HOTOH                                0                0
#
#             Contract_Month-to-month  Contract_One year  Contract_Two year  \
# customerID
# 0002-ORFBO                        0                  1                  0
# 0003-MKNFE                        1                  0                  0
# 0004-TLHLJ                        1                  0                  0
# 0011-IGKFF                        1                  0                  0
# 0013-EXCHZ                        1                  0                  0
# ...                             ...                ...                ...
# 9987-LUTYD                        0                  1                  0
# 9992-RRAMN                        1                  0                  0
# 9992-UJOEL                        1                  0                  0
# 9993-LHIEB                        0                  0                  1
# 9995-HOTOH                        0                  0                  1
#
#             PaperlessBilling_No  PaperlessBilling_Yes
# customerID
# 0002-ORFBO                    0                     1
# 0003-MKNFE                    1                     0
# 0004-TLHLJ                    0                     1
# 0011-IGKFF                    0                     1
# 0013-EXCHZ                    0                     1
# ...                         ...                   ...
# 9987-LUTYD                    1                     0
# 9992-RRAMN                    0                     1
# 9992-UJOEL                    0                     1
# 9993-LHIEB                    1                     0
# 9995-HOTOH                    1                     0
#
# [7032 rows x 30 columns]

# %%
# Scaling the numeric columns
for column in ['tenure','Monthly','Total']:
  data[column] = (data[column]-data[column].mean())/data[column].std()
data
# Out:
#             Churn    tenure   Monthly     Total  SeniorCitizen_No  \
# customerID
# 0002-ORFBO      0 -0.954228  0.026650 -0.745554                 1
# 0003-MKNFE      0 -0.954228 -0.162807 -0.768009                 1
# 0004-TLHLJ      1 -1.157934  0.302526 -0.883393                 1
# 0011-IGKFF      1 -0.791264  1.103564 -0.461207                 0
# 0013-EXCHZ      1 -1.198675  0.634907 -0.889327                 0
# ...           ...       ...       ...       ...               ...
# 9987-LUTYD      0 -0.791264 -0.320688 -0.679557                 1
# 9992-RRAMN      1 -0.424595  0.674793 -0.180698                 1
# 9992-UJOEL      0 -1.239416 -0.481893 -0.966375                 1
# 9993-LHIEB      0  1.408753  0.101436  1.034224                 1
# 9995-HOTOH      0  1.245789 -0.192721  0.628338                 1
#
#             SeniorCitizen_Yes  Partner_No  Partner_Yes  Dependents_No  \
# customerID
# 0002-ORFBO                  0           0            1              0
# 0003-MKNFE                  0           1            0              1
# 0004-TLHLJ                  0           1            0              1
# 0011-IGKFF                  1           0            1              1
# 0013-EXCHZ                  1           0            1              1
# ...                       ...         ...          ...            ...
# 9987-LUTYD                  0           1            0              1
# 9992-RRAMN                  0           0            1              1
# 9992-UJOEL                  0           1            0              1
# 9993-LHIEB                  0           0            1              0
# 9995-HOTOH                  0           0            1              0
#
#             Dependents_Yes  ...  DeviceProtection_No internet service  \
# customerID                  ...
# 0002-ORFBO               1  ...                                     0
# 0003-MKNFE               0  ...                                     0
# 0004-TLHLJ               0  ...                                     0
# 0011-IGKFF               0  ...                                     0
# 0013-EXCHZ               0  ...                                     0
# ...                    ...  ...                                   ...
# 9987-LUTYD               0  ...                                     0
# 9992-RRAMN               0  ...                                     0
# 9992-UJOEL               0  ...                                     0
# 9993-LHIEB               1  ...                                     0
# 9995-HOTOH               1  ...                                     0
#
#             DeviceProtection_Yes  TechSupport_No  \
# customerID
# 0002-ORFBO                     0               0
# 0003-MKNFE                     0               1
# 0004-TLHLJ                     1               1
# 0011-IGKFF                     1               1
# 0013-EXCHZ                     0               0
# ...                          ...             ...
# 9987-LUTYD                     0               0
# 9992-RRAMN                     0               1
# 9992-UJOEL                     0               1
# 9993-LHIEB                     1               0
# 9995-HOTOH                     1               1
#
#             TechSupport_No internet service  TechSupport_Yes  \
# customerID
# 0002-ORFBO                                0                1
# 0003-MKNFE                                0                0
# 0004-TLHLJ                                0                0
# 0011-IGKFF                                0                0
# 0013-EXCHZ                                0                1
# ...                                     ...              ...
# 9987-LUTYD                                0                1
# 9992-RRAMN                                0                0
# 9992-UJOEL                                0                0
# 9993-LHIEB                                0                1
# 9995-HOTOH                                0                0
#
#             Contract_Month-to-month  Contract_One year  Contract_Two year  \
# customerID
# 0002-ORFBO                        0                  1                  0
# 0003-MKNFE                        1                  0                  0
# 0004-TLHLJ                        1                  0                  0
# 0011-IGKFF                        1                  0                  0
# 0013-EXCHZ                        1                  0                  0
# ...                             ...                ...                ...
# 9987-LUTYD                        0                  1                  0
# 9992-RRAMN                        1                  0                  0
# 9992-UJOEL                        1                  0                  0
# 9993-LHIEB                        0                  0                  1
# 9995-HOTOH                        0                  0                  1
#
#             PaperlessBilling_No  PaperlessBilling_Yes
# customerID
# 0002-ORFBO                    0                     1
# 0003-MKNFE                    1                     0
# 0004-TLHLJ                    0                     1
# 0011-IGKFF                    0                     1
# 0013-EXCHZ                    0                     1
# ...                         ...                   ...
# 9987-LUTYD                    1                     0
# 9992-RRAMN                    0                     1
# 9992-UJOEL                    0                     1
# 9993-LHIEB                    1                     0
# 9995-HOTOH                    1                     0
#
# [7032 rows x 30 columns]

# %%
# Sampling the training, cross-evaluation and test sets.
training_set = data.sample(frac=0.6,axis=0)
remaining = data.drop(training_set.index)
cv_set = remaining.sample(frac=0.5,axis=0)
test_set = remaining.drop(cv_set.index)

# %%
# Getting the features and the target for each of the training, cross-evaluation and test sets.
features_train = training_set.drop('Churn',axis=1)
target_train = training_set['Churn']
features_cv = cv_set.drop('Churn',axis=1)
target_cv = cv_set['Churn']
features_test = test_set.drop('Churn',axis=1)
target_test = test_set['Churn']

# %%
# Testing the balance in the target variable for all 3 sets.
print(f'The proportion of positive ocurrences in the training set is {(np.count_nonzero(target_train)/target_train.shape[0])*100:.2f}%')
print(f'The proportion of positive ocurrences in the cross-evaluation set is {(np.count_nonzero(target_cv)/target_cv.shape[0])*100:.2f}%')
print(f'The proportion of positive ocurrences in the test set is {(np.count_nonzero(target_test)/target_test.shape[0])*100:.2f}%')
# Out:
# The proportion of positive ocurrences in the training set is 26.38%
# The proportion of positive ocurrences in the cross-evaluation set is 27.38%
# The proportion of positive ocurrences in the test set is 26.37%

# %%
# Oversampling to fix the imbalance in the training set.
training_set_bal = training_set
for i in range(1,10):
 if np.count_nonzero(training_set_bal['Churn'])/training_set_bal['Churn'].shape[0] < 0.5:
  training_set_bal = pd.concat([training_set_bal,training_set.query('Churn==1')])

training_set_bal = training_set_bal.sample(frac=1)
features_train = training_set_bal.drop('Churn',axis=1)
target_train = training_set_bal['Churn']
print(f'The proportion of positive ocurrences in the training set is {(np.count_nonzero(target_train)/target_train.shape[0])*100:.2f}%')
# Out:
# The proportion of positive ocurrences in the training set is 51.81%

# %%
# Converting to numpy array.
x_train = features_train.to_numpy()
y_train = target_train.to_numpy()
x_cv = features_cv.to_numpy()
y_cv = target_cv.to_numpy()
x_test = features_test.to_numpy()
y_test = target_test.to_numpy()

# %%
# Importing the libraries.
import tensorflow as tf
from sklearn.metrics import confusion_matrix

# %%
# Creating and trainning the first model of the neural network. For this project the most important metric is the recall, since false negatives are a lot more concerning when it comes to Churn rate prediction,
# then false positives.

callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss',factor=0.5,patience=5,min_lr=0.0001)

model1 = tf.keras.models.Sequential([

    tf.keras.layers.Dense(units=32,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=16,activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(units=1,activation='sigmoid')
])
model1.compile(loss=tf.keras.losses.BinaryCrossentropy(),
               optimizer=tf.keras.optimizers.Adam(0.001),
               metrics=[tf.keras.metrics.BinaryAccuracy(),tf.keras.metrics.Recall()]
               )
model1.fit(x_train,y_train,epochs=100,callbacks=[callback],validation_data=(x_cv,y_cv))
# Out:
# Epoch 1/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - binary_accuracy: 0.6590 - loss: 0.6056 - recall: 0.7116 - val_binary_accuracy: 0.7347 - val_loss: 0.5282 - val_recall: 0.8130 - learning_rate: 0.0010
# Epoch 2/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - binary_accuracy: 0.7320 - loss: 0.5344 - recall: 0.7759 - val_binary_accuracy: 0.7169 - val_loss: 0.5399 - val_recall: 0.8260 - learning_rate: 0.0010
# Epoch 3/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.7473 - loss: 0.5206 - recall: 0.8116 - val_binary_accuracy: 0.7354 - val_loss: 0.5032 - val_recall: 0.8052 - learning_rate: 0.0010
# Epoch 4/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7551 - loss: 0.5097 - recall: 0.8159 - val_binary_accuracy: 0.7312 - val_loss: 0.4978 - val_recall: 0.8000 - learning_rate: 0.0010
# Epoch 5/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7709 - loss: 0.4930 - recall: 0.8314 - val_binary_accuracy: 0.7205 - val_loss: 0.5127 - val_recall: 0.8182 - learning_rate: 0.0010
# Epoch 6/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7538 - loss: 0.5029 - recall: 0.8208 - val_binary_accuracy: 0.7361 - val_loss: 0.5030 - val_recall: 0.7870 - learning_rate: 0.0010
# Epoch 7/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7714 - loss: 0.4904 - recall: 0.8373 - val_binary_accuracy: 0.7383 - val_loss: 0.4941 - val_recall: 0.7922 - learning_rate: 0.0010
# Epoch 8/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7608 - loss: 0.4992 - recall: 0.8111 - val_binary_accuracy: 0.7098 - val_loss: 0.5335 - val_recall: 0.8442 - learning_rate: 0.0010
# Epoch 9/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7627 - loss: 0.4987 - recall: 0.8283 - val_binary_accuracy: 0.7333 - val_loss: 0.4984 - val_recall: 0.8000 - learning_rate: 0.0010
# Epoch 10/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.7631 - loss: 0.4959 - recall: 0.8223 - val_binary_accuracy: 0.7248 - val_loss: 0.5102 - val_recall: 0.8156 - learning_rate: 0.0010
# Epoch 11/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.7598 - loss: 0.5013 - recall: 0.8258 - val_binary_accuracy: 0.7255 - val_loss: 0.5083 - val_recall: 0.8052 - learning_rate: 0.0010
# Epoch
100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.7906 - loss: 0.4448 - recall: 0.8599 - val_binary_accuracy: 0.7404 - val_loss: 0.5108 - val_recall: 0.8052 - learning_rate: 1.2500e-04
# Epoch 91/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary_accuracy: 0.7944 - loss: 0.4440 - recall: 0.8771 - val_binary_accuracy: 0.7418 - val_loss: 0.5072 - val_recall: 0.8000 - learning_rate: 1.2500e-04
# Epoch 92/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.8010 - loss: 0.4361 - recall: 0.8735 - val_binary_accuracy: 0.7425 - val_loss: 0.5094 - val_recall: 0.8026 - learning_rate: 1.2500e-04
# Epoch 93/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary_accuracy: 0.7992 - loss: 0.4286 - recall: 0.8649 - val_binary_accuracy: 0.7432 - val_loss: 0.5084 - val_recall: 0.8026 - learning_rate: 1.2500e-04
# Epoch 94/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary_accuracy: 0.7946 - loss: 0.4385 - recall: 0.8593 - val_binary_accuracy: 0.7390 - val_loss: 0.5097 - val_recall: 0.8182 - learning_rate: 1.0000e-04
# Epoch 95/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary_accuracy: 0.7841 - loss: 0.4471 - recall: 0.8685 - val_binary_accuracy: 0.7376 - val_loss: 0.5109 - val_recall: 0.8182 - learning_rate: 1.0000e-04
# Epoch 96/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - binary_accuracy: 0.7941 - loss: 0.4387 - recall: 0.8743 - val_binary_accuracy: 0.7390 - val_loss: 0.5097 - val_recall: 0.8208 - learning_rate: 1.0000e-04
# Epoch 97/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary_accuracy: 0.7886 - loss: 0.4452 - recall: 0.8583 - val_binary_accuracy: 0.7390 - val_loss: 0.5088 - val_recall: 0.8182 - learning_rate: 1.0000e-04
# Epoch 98/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary_accuracy: 0.7995 - loss: 0.4327 - recall: 0.8784 - val_binary_accuracy: 0.7418 - val_loss: 0.5084 - val_recall: 0.7974 - learning_rate: 1.0000e-04
# Epoch 99/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary_accuracy: 0.7903 - loss: 0.4454 - recall: 0.8672 - val_binary_accuracy: 0.7376 - val_loss: 0.5087 - val_recall: 0.8182 - learning_rate: 1.0000e-04
# Epoch 100/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - binary_accuracy: 0.7895 - loss: 0.4499 - recall: 0.8621 - val_binary_accuracy: 0.7368 - val_loss: 0.5093 - val_recall: 0.8156 - learning_rate: 1.0000e-04

# %%
# Evaluating the model 1.
model1.evaluate(x_test,y_test)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.7550 - loss: 0.4860 - recall: 0.8373
# [0.5043119788169861, 0.7512437701225281, 0.8463611602783203]

# %%
# Attempting a different model.
callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='loss',factor=0.5,patience=5,min_lr=0.0001)


model2 = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=128,activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=64,activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=32,activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=16,activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=8,activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(units=1,activation='sigmoid')
])
model2.compile(loss= tf.keras.losses.BinaryCrossentropy(),
               optimizer= tf.keras.optimizers.Adam(0.001),
               metrics=[tf.keras.metrics.BinaryAccuracy(),tf.keras.metrics.Recall()])
history = model2.fit(x_train,y_train,epochs=100,callbacks=[callback],validation_data=(x_cv,y_cv))
# Out:
# Epoch 1/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - binary_accuracy: 0.5230 - loss: 0.8120 - recall_1: 0.6292 - val_binary_accuracy: 0.3001 - val_loss: 0.8152 - val_recall_1: 1.0000 - learning_rate: 0.0010
# Epoch 2/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.5879 - loss: 0.6958 - recall_1: 0.7246 - val_binary_accuracy: 0.4253 - val_loss: 0.7607 - val_recall_1: 0.9844 - learning_rate: 0.0010
# Epoch 3/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.6084 - loss: 0.6633 - recall_1: 0.7709 - val_binary_accuracy: 0.5121 - val_loss: 0.6984 - val_recall_1: 0.9714 - learning_rate: 0.0010
# Epoch 4/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0
- val_recall_1: 0.9143 - learning_rate: 0.0010
# Epoch 24/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7289 - loss: 0.5657 - recall_1: 0.8778 - val_binary_accuracy: 0.6294 - val_loss: 0.5791 - val_recall_1: 0.9143 - learning_rate: 0.0010
# Epoch 25/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7270 - loss: 0.5671 - recall_1: 0.8785 - val_binary_accuracy: 0.6337 - val_loss: 0.5721 - val_recall_1: 0.9065 - learning_rate: 0.0010
# Epoch 26/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7311 - loss: 0.5727 - recall_1: 0.8687 - val_binary_accuracy: 0.6380 - val_loss: 0.5682 - val_recall_1: 0.9091 - learning_rate: 0.0010
# Epoch 27/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7218 - loss: 0.5609 - recall_1: 0.8600 - val_binary_accuracy: 0.6330 - val_loss: 0.5702 - val_recall_1: 0.9143 - learning_rate: 0.0010
# Epoch 28/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7350 - loss: 0.5518 - recall_1: 0.8753 - val_binary_accuracy: 0.6266 - val_loss: 0.5655 - val_recall_1: 0.9117 - learning_rate: 0.0010
# Epoch 29/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7327 - loss: 0.5528 - recall_1: 0.8839 - val_binary_accuracy: 0.6366 - val_loss: 0.5594 - val_recall_1: 0.9117 - learning_rate: 0.0010
# Epoch 30/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7357 - loss: 0.5591 - recall_1: 0.8707 - val_binary_accuracy: 0.6387 - val_loss: 0.5605 - val_recall_1: 0.9117 - learning_rate: 0.0010
# Epoch 31/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7283 - loss: 0.5591 - recall_1: 0.8714 - val_binary_accuracy: 0.6408 - val_loss: 0.5629 - val_recall_1: 0.9039 - learning_rate: 0.0010
# Epoch 32/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.7295 - loss: 0.5544 - recall_1: 0.8595 - val_binary_accuracy: 0.6316 - val_loss: 0.5718 - val_recall_1: 0.9091 - learning_rate: 0.0010
# Epoch 33/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.7365 - loss: 0.5562 - recall_1: 0.8825 - val_binary_accuracy: 0.6337 - val_loss: 0.5624 - val_recall_1: 0.9143 - learning_rate: 0.0010
# Epoch 34/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.7311 - loss: 0.5604 - recall_1: 0.8631 - val_binary_accuracy: 0.6479 - val_loss: 0.5571 - val_recall_1: 0.9013 - learning_rate: 0.0010
# Epoch 35/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7212 - loss: 0.5631 - recall_1: 0.8576 - val_binary_accuracy: 0.6316 - val_loss: 0.5753 - val_recall_1: 0.9143 - learning_rate: 0.0010
# Epoch 36/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7323 - loss: 0.5564 - recall_1: 0.8686 - val_binary_accuracy: 0.6465 - val_loss: 0.5588 - val_recall_1: 0.8961 - learning_rate: 0.0010
# Epoch 37/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7405 - loss: 0.5538 - recall_1: 0.8700 - val_binary_accuracy: 0.6529 - val_loss: 0.5565 - val_recall_1: 0.8961 - learning_rate: 0.0010
# Epoch 38/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7440 - loss: 0.5430 - recall_1: 0.8691 - val_binary_accuracy: 0.6529 - val_loss: 0.5513 - val_recall_1: 0.8883 - learning_rate: 0.0010
# Epoch 39/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.7289 - loss: 0.5654 - recall_1: 0.8600 - val_binary_accuracy: 0.6515 - val_loss: 0.5530 - val_recall_1: 0.8805 - learning_rate: 0.0010
# Epoch 40/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7356 - loss: 0.5500 - recall_1: 0.8687 - val_binary_accuracy: 0.6415 - val_loss: 0.5514 - val_recall_1: 0.9117 - learning_rate: 0.0010
# Epoch 41/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7309 - loss: 0.5518 - recall_1: 0.8607 - val_binary_accuracy: 0.6387 - val_loss: 0.5542 - val_recall_1: 0.9039 - learning_rate: 0.0010
# Epoch 42/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7433 - loss: 0.5449 - recall_1: 0.8776 - val_binary_accuracy: 0.6586 - val_loss: 0.5496 - val_recall_1: 0.8935 - learning_rate: 0.0010
# Epoch 43/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7318 - loss: 0.5575 - recall_1: 0.8567 - val_binary_accuracy: 0.6515 - val_loss: 0.5626 - val_recall_1: 0.9039 - learning_rate: 0.0010
# Epoch 44/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7351 - loss: 0.5471 - recall_1: 0.8643 - val_binary_accuracy: 0.6600 - val_loss: 0.5457 - val_recall_1: 0.8961 - learning_rate: 0.0010
# Epoch 45/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7410 - loss: 0.5468 - recall_1: 0.8678 - val_binary_accuracy: 0.6572 - val_loss: 0.5468 - val_recall_1: 0.8883 - learning_rate: 0.0010
# Epoch 46/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - binary_accuracy: 0.7458 - loss: 0.5379 - recall_1: 0.8575 - val_binary_accuracy: 0.6529 - val_loss: 0.5523 - val_recall_1: 0.8883 - learning_rate: 0.0010
# Epoch 47/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.7399 - loss: 0.5514 - recall_1: 0.8640 - val_binary_accuracy: 0.6572 - val_loss: 0.5433 - val_recall_1: 0.8857 - learning_rate: 0.0010
# Epoch 48/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7383 - loss: 0.5481 - recall_1: 0.8576 - val_binary_accuracy: 0.6664 - val_loss: 0.5404 - val_recall_1: 0.8753 - learning_rate: 0.0010
# Epoch 49/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7298 - loss: 0.5489 - recall_1: 0.8508 - val_binary_accuracy: 0.6373 - val_loss: 0.5581 - val_recall_1: 0.8961 - learning_rate: 0.0010
# Epoch 50/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7405 - loss: 0.5373 - recall_1: 0.8666 - val_binary_accuracy: 0.6408 - val_loss: 0.5626 - val_recall_1: 0.9013 - learning_rate: 0.0010
# Epoch 51/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.7347 - loss: 0.5536 - recall_1: 0.8532 - val_binary_accuracy: 0.6415 - val_loss: 0.5586 - val_recall_1: 0.9039 - learning_rate: 5.0000e-04
# Epoch 52/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7391 - loss: 0.5458 - recall_1: 0.8556 - val_binary_accuracy: 0.6415 - val_loss: 0.5534 - val_recall_1: 0.8987 - learning_rate: 5.0000e-04
# Epoch 53/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7562 - loss: 0.5345 - recall_1: 0.8837 - val_binary_accuracy: 0.6486 - val_loss: 0.5578 - val_recall_1: 0.9013 - learning_rate: 5.0000e-04
# Epoch 54/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7381 - loss: 0.5355 - recall_1: 0.8716 - val_binary_accuracy: 0.6444 - val_loss: 0.5514 - val_recall_1: 0.8987 - learning_rate: 5.0000e-04
# Epoch 55/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7399 - loss: 0.5365 - recall_1: 0.8710 - val_binary_accuracy: 0.6472 - val_loss: 0.5541 - val_recall_1: 0.8987 - learning_rate: 5.0000e-04
# Epoch 56/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7411 - loss: 0.5348 - recall_1: 0.8624 - val_binary_accuracy: 0.6543 - val_loss: 0.5443 - val_recall_1: 0.8909 - learning_rate: 5.0000e-04
# Epoch 57/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7475 - loss: 0.5376 - recall_1: 0.8684 - val_binary_accuracy: 0.6458 - val_loss: 0.5501 - val_recall_1: 0.8935 - learning_rate: 5.0000e-04
# Epoch 58/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.7375 - loss: 0.5422 - recall_1: 0.8583 - val_binary_accuracy: 0.6494 - val_loss: 0.5547 - val_recall_1: 0.8961 - learning_rate: 5.0000e-04
# Epoch 59/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.7346 - loss: 0.5485 - recall_1: 0.8485 - val_binary_accuracy: 0.6479 - val_loss: 0.5523 - val_recall_1: 0.8987 - learning_rate: 2.5000e-04
# Epoch 60/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.7270 - loss: 0.5504 - recall_1: 0.8545 - val_binary_accuracy: 0.6515 - val_loss: 0.5486 - val_recall_1: 0.8935 - learning_rate: 2.5000e-04
# Epoch 61/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7437 - loss: 0.5446 - recall_1: 0.8699 - val_binary_accuracy: 0.6479 - val_loss: 0.5518 - val_recall_1: 0.8987 - learning_rate: 2.5000e-04
# Epoch 62/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.7447 - loss: 0.5336 - recall_1: 0.8697 - val_binary_accuracy: 0.6543 - val_loss: 0.5463 - val_recall_1: 0.8935 - learning_rate: 2.5000e-04
# Epoch 63/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7359 - loss: 0.5408 - recall_1: 0.8578 - val_binary_accuracy: 0.6472 - val_loss: 0.5534 - val_recall_1: 0.8987 - learning_rate: 2.5000e-04
# Epoch 64/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7527 - loss: 0.5352 - recall_1: 0.8733 - val_binary_accuracy: 0.6543 - val_loss: 0.5487 - val_recall_1: 0.8935 - learning_rate: 2.5000e-04
# Epoch 65/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7412 - loss: 0.5377 - recall_1: 0.8684 - val_binary_accuracy: 0.6465 - val_loss: 0.5507 - val_recall_1: 0.8935 - learning_rate: 1.2500e-04
# Epoch 66/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7473 - loss: 0.5337 - recall_1: 0.8617 - val_binary_accuracy: 0.6522 - val_loss: 0.5523 - val_recall_1: 0.8935 - learning_rate: 1.2500e-04
# Epoch 67/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7526 - loss: 0.5178 - recall_1: 0.8854 - val_binary_accuracy: 0.6472 - val_loss: 0.5530 - val_recall_1: 0.8935 - learning_rate: 1.2500e-04
# Epoch 68/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7442 - loss: 0.5448 - recall_1: 0.8734 - val_binary_accuracy: 0.6501 - val_loss: 0.5521 - val_recall_1: 0.8961 - learning_rate: 1.2500e-04
# Epoch 69/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7355 - loss: 0.5418 - recall_1: 0.8588 - val_binary_accuracy: 0.6501 - val_loss: 0.5542 - val_recall_1: 0.8961 - learning_rate: 1.2500e-04
# Epoch 70/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7507 - loss: 0.5369 - recall_1: 0.8691 - val_binary_accuracy: 0.6529 - val_loss: 0.5499 - val_recall_1: 0.8935 - learning_rate: 1.2500e-04
# Epoch 71/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7503 - loss: 0.5317 - recall_1: 0.8794 - val_binary_accuracy: 0.6508 - val_loss: 0.5493 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 72/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.7422 - loss: 0.5378 - recall_1: 0.8590 - val_binary_accuracy: 0.6522 - val_loss: 0.5489 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 73/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.7382 - loss: 0.5442 - recall_1: 0.8635 - val_binary_accuracy: 0.6508 - val_loss: 0.5481 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 74/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.7575 - loss: 0.5291 - recall_1: 0.8711 - val_binary_accuracy: 0.6486 - val_loss: 0.5532 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 75/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7452 - loss: 0.5251 - recall_1: 0.8742 - val_binary_accuracy: 0.6486 - val_loss: 0.5518 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 76/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7474 - loss: 0.5319 - recall_1: 0.8668 - val_binary_accuracy: 0.6494 - val_loss: 0.5515 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 77/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.7397 - loss: 0.5335 - recall_1: 0.8702 - val_binary_accuracy: 0.6543 - val_loss: 0.5473 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 78/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7546 - loss: 0.5340 - recall_1: 0.8784 - val_binary_accuracy: 0.6543 - val_loss: 0.5496 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 79/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7530 - loss: 0.5308 - recall_1: 0.8811 - val_binary_accuracy: 0.6543 - val_loss: 0.5494 - val_recall_1: 0.8909 - learning_rate: 1.0000e-04
# Epoch 80/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7536 - loss: 0.5333 - recall_1: 0.8754 - val_binary_accuracy: 0.6451 - val_loss: 0.5559 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 81/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7455 - loss: 0.5331 - recall_1: 0.8719 - val_binary_accuracy: 0.6593 - val_loss: 0.5466 - val_recall_1: 0.8909 - learning_rate: 1.0000e-04
# Epoch 82/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7472 - loss: 0.5231 - recall_1: 0.8654 - val_binary_accuracy: 0.6607 - val_loss: 0.5473 - val_recall_1: 0.8909 - learning_rate: 1.0000e-04
# Epoch 83/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7413 - loss: 0.5345 - recall_1: 0.8686 - val_binary_accuracy: 0.6600 - val_loss: 0.5467 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04
# Epoch 84/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - binary_accuracy: 0.7407 - loss: 0.5354 - recall_1: 0.8817 - val_binary_accuracy: 0.6536 - val_loss: 0.5516 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04
# Epoch 85/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.7429 - loss: 0.5409 - recall_1: 0.8716 - val_binary_accuracy: 0.6558 - val_loss: 0.5536 - val_recall_1: 0.8909 - learning_rate: 1.0000e-04
# Epoch 86/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.7466 - loss: 0.5166 - recall_1: 0.8743 - val_binary_accuracy: 0.6579 - val_loss: 0.5503 - val_recall_1: 0.8909 - learning_rate: 1.0000e-04
# Epoch 87/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7490 - loss: 0.5352 - recall_1: 0.8713 - val_binary_accuracy: 0.6479 - val_loss: 0.5555 - val_recall_1: 0.8935 - learning_rate: 1.0000e-04
# Epoch 88/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7462 - loss: 0.5223 - recall_1: 0.8728 - val_binary_accuracy: 0.6515 - val_loss: 0.5496 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04
# Epoch 89/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7355 - loss: 0.5417 - recall_1: 0.8685 - val_binary_accuracy: 0.6550 - val_loss: 0.5489 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04
# Epoch 90/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7567 - loss: 0.5256 - recall_1: 0.8639 - val_binary_accuracy: 0.6558 - val_loss: 0.5492 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04
# Epoch 91/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7508 - loss: 0.5198 - recall_1: 0.8767 - val_binary_accuracy: 0.6572 - val_loss: 0.5484 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04
# Epoch 92/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7504 - loss: 0.5299 - recall_1: 0.8767 - val_binary_accuracy: 0.6572 - val_loss: 0.5493 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04
# Epoch 93/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7450 - loss: 0.5401 - recall_1: 0.8676 - val_binary_accuracy: 0.6550 - val_loss: 0.5509 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04
# Epoch 94/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7543 - loss: 0.5267 - recall_1: 0.8835 - val_binary_accuracy: 0.6543 - val_loss: 0.5489 - val_recall_1: 0.8909 - learning_rate: 1.0000e-04
# Epoch 95/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7605 - loss: 0.5214 - recall_1: 0.8840 - val_binary_accuracy: 0.6529 - val_loss: 0.5502 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04
# Epoch 96/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7469 - loss: 0.5391 - recall_1: 0.8709 - val_binary_accuracy: 0.6550 - val_loss: 0.5492 - val_recall_1: 0.8909 - learning_rate: 1.0000e-04
# Epoch 97/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - binary_accuracy: 0.7543 - loss: 0.5387 - recall_1: 0.8772 - val_binary_accuracy: 0.6536 - val_loss: 0.5533 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04
# Epoch 98/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.7476 - loss: 0.5403 - recall_1: 0.8700 - val_binary_accuracy: 0.6536 - val_loss: 0.5515 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04
# Epoch 99/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.7379 - loss: 0.5407 - recall_1: 0.8655 - val_binary_accuracy: 0.6494 - val_loss: 0.5559 - val_recall_1: 0.8909 - learning_rate: 1.0000e-04
# Epoch 100/100
# 202/202 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - binary_accuracy: 0.7439 - loss: 0.5356 - recall_1: 0.8664 - val_binary_accuracy: 0.6543 - val_loss: 0.5497 - val_recall_1: 0.8883 - learning_rate: 1.0000e-04

# %%
# Evaluating model 2.
model2.evaluate(x_test,y_test)
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.6788 - loss: 0.5258 - recall_1: 0.9243
# [0.5323383212089539, 0.6687988638877869, 0.9164420366287231]

# %%
# Even though the model has not reached a very high level of acuracy,  it achieved around 90% or more of recall on the test set. That means the the inaccuracies of the model
#  are mostly due to false positives, which do not represent a risk of income loss to the company as false negatives do. The high recall obtained in the validation and test sets
# indicates this model is very effective at reversing Churn rates since it allows for targeted marketing practices to offer the services and contract models our analysis showed
# to be related to lower client evasion. All that's left now is saving the model for posterior deployment.
model2.save('ModelChurn.keras')
